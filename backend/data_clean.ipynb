# %%
import pandas as pd
df = pd.read_csv('live_shipments.csv')
df.drop(columns=['event_type'], inplace=True)
df.to_csv('live_shipments.csv', index=False)
# Out:
#     shipment_id    carrier weather  shipment_value  warehouse_load_pct  \
# 0   oB-56947942      Swift   Clear            1809                  87
# 1   Pb-89346154   BlueDart   Clear             600                  49
# 2   nl-11821062      Swift   Clear           11453                  85
# 3   ko-27943858      Swift     Fog           12340                  64
# 4   dx-31203927  Delhivery   Clear           11562                  52
# ..          ...        ...     ...             ...                 ...
# 95  LX-35598247      Swift   Clear            3715                  31
# 96  UX-33889425      Swift   Clear           13433                  83
# 97  NB-09442653   BlueDart   Clear            5367                  68
# 98  NG-22109572  Delhivery     Fog           12538                  95
# 99  lI-97481840   BlueDart   Clear            8942                  34
#
#     traffic_density             planned_arrival  current_delay_minutes  \
# ...

# %%
df2 = pd.read_csv('historical_logistics.csv')
df2.drop(columns=['event_type'], inplace=True)
df2.to_csv('historical_logistics2.csv', index=False)
# Out:
#      shipment_id    carrier     weather  shipment_value  warehouse_load_pct  \
# 0    FJ-82823588  Delhivery  Heavy Rain           10753                  91
# 1    kq-40251081  Delhivery       Clear            5202                  78
# 2    YH-75059296      Swift         Fog            7599                 100
# 3    Wh-78892433   BlueDart         Fog           12401                  30
# 4    km-65944917   BlueDart         Fog           13820                  73
# ..           ...        ...         ...             ...                 ...
# 995  zT-77844970  Delhivery  Heavy Rain            5176                  43
# 996  Wb-54841561      Swift     Cyclone            1591                  62
# 997  GI-34423263   BlueDart       Clear            9382                  67
# 998  at-81911581  Delhivery  Heavy Rain            5328                  95
# 999  JK-43799249      Swift  Heavy Rain           12994                  81
#
# ...
